# %% [markdown]
# # Prediction of Per Capita Income of India

# %% [markdown]
# The following predcition is made upon the Data which is till 2020.<br>
# The following prediction is not accurate as there is actual growth of <b>18.12%</b> form 2020 to 2021<br>
# The Graph PerCapitaIncome till 2020:
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### reading the csv file

# %%
df=pd.read_csv('india_per_capita_income.csv')
df.head()
# Out:
#    year   perCapita
# 0  1970  103.639254
# 1  1971  109.250449
# 2  1972  113.335667
# 3  1973  132.593614
# 4  1974  149.917784

# %% [markdown]
# ### Ploting the Scatter Graph of the following DataFrame

# %%
plt.xlabel('year')
plt.ylabel('per Capita Income [US$]')
plt.scatter(df.year,df.perCapita,color='red',marker='+')
plt.show()

# %%
new_df=df.drop('perCapita',axis=1)

# %%
per=df.perCapita

# %% [markdown]
# ### Using Linear Regression for prediction

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,per)
# Out:
# LinearRegression()

# %%
predict_of=predict_of.rename(columns={0:'year'})

# %%
predict_of
# Out:
#    year
# 0  2021
# 1  2022
# 2  2023
# 3  2024

# %%
p=reg.predict(predict_of)

# %%
prediction=pd.DataFrame({'year':predict_of['year'],'perCapita':p})

# %% [markdown]
# ### These are the following prediction

# %%
prediction
# Out:
#    year    perCapita
# 0  2021  1370.555206
# 1  2022  1400.930361
# 2  2023  1431.305515
# 3  2024  1461.680669

# %% [markdown]
# ### The Regression line of the following data is

# %%
plt.xlabel('year')
plt.ylabel('per Capita Income [US$]')
plt.scatter(df.year,df.perCapita,color='red',marker='+')
plt.plot(df.year, reg.predict(df[['year']]), color='blue')
plt.show()
